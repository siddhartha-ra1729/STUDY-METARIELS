# %%
import matplotlib.pyplot as plt
x=[2,3,4,6]
y=[2,4,6,8]
c=["r","y","g","b"]

plt.bar(x,y,color=c)


plt.show()

# %% [markdown]
# # bar plot

# %%
import matplotlib.pyplot as plt
import numpy as np

x=["python","c","c++","java"]
y=[35,46,52,31]
z=[34,32,29,40]
width=0.3
p=np.arange(len(x))
p1=[j+width for j in p]

plt.xlabel("language",fontsize=5)
plt.ylabel("no")
plt.title("wskhuu")

plt.bar(p,y,width,color="r",label="chompa")
plt.bar(p1,z,width,color="g",label="kumpa")

plt.xticks(p+width/2,x)
plt.legend()
plt.show()

# %% [markdown]
# # scatter plot

# %%
import matplotlib.pyplot as plt
DAY=[1,2,3,4,5,6,7]
no=[2,4,5,1,8,3,9]
colors=["r","g","b","b","y","g","y"]
sizes=[300,45,12,43,23,68,12]
plt.scatter(DAY,no,c=colors,s=sizes,alpha=0.5)
plt.title("scatter plot",fontsize=10)
plt.xlabel("DAY",fontsize=10)
plt.ylabel("no",fontsize=10)
plt.show()

# %%
DAY=[1,2,3,4,5,6,7]
no=[2,4,5,1,8,3,9]
colors=["r","g","b","b","y","g","y"]
sizes=[300,450,12,43,230,68,120]
plt.scatter(DAY,no,c=colors,s=sizes,alpha=0.5,marker='*',edgecolor='r',linewidth=4)
plt.title("scatter plot",fontsize=10)
plt.xlabel("DAY",fontsize=10)
plt.ylabel("no",fontsize=10)
plt.show()

# %%
DAY=[1,2,3,4,5,6,7]
no=[2,4,5,1,8,3,9]
colors=[10,45,49,23,78,12,67]
sizes=[300,450,12,43,230,68,120]
plt.scatter(DAY,no,c=colors,s=sizes,cmap='viridis')
plt.title("scatter plot",fontsize=10)
plt.xlabel("DAY",fontsize=10)
plt.ylabel("no",fontsize=10)
plt.colorbar()
plt.show()

# %%
DAY=[1,2,3,4,5,6,7]
no=[2,4,5,1,8,3,9]
colors=[10,45,49,23,78,12,67]
sizes=[300,450,12,43,230,68,120]
plt.scatter(DAY,no,c=colors,s=sizes,cmap='BrBG')  #differenent colormaps

t=plt.colorbar()
t.set_lebel("colorbar")

plt.title("scatter plot",fontsize=10)
plt.xlabel("DAY",fontsize=10)
plt.ylabel("no",fontsize=10)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20532\1810675222.py in <module>
#       6
#       7 t=plt.colorbar()
# ----> 8 t.set_lebel("colorbar")
#       9
#      10 plt.title("scatter plot",fontsize=10)
#
# AttributeError: 'Colorbar' object has no attribute 'set_lebel'

# %% [markdown]
# # BAR PLOT

# %%
import matplotlib.pyplot as plt

# %%
x=['python','c++','java','typescript','wordspress']
y=[45,56,78,43,12]
z=[0.1,0.9,0.7,0.4,0.7]

import numpy as np

p=np.arange(len(x))
width=0.3
p1=[j+width for j in p]

plt.xlabel('language',fontsize=14)
plt.ylabel('range',fontsize=14)
plt.title('language vs  range',fontsize=14)
Color=["r","b","y","g","o"]
#plt.bar(x,y,width=0.5,align='center',color='pink',edgecolor='red',linewidth=4,linestyle=':',alpha=0.4)
#width=0.3

plt.bar(p,y,width,color="r",label="sidd")
plt.bar(p1,z,width,color="y",label="raju")

plt.xticks(p+width/2,x,rotation=12)
plt.legend()
plt.show()

# %%
x=['python','c++','java','typescript','wordspress']
y=[45,56,78,43,12]
z=[0.1,0.9,0.7,0.4,0.7]





plt.xlabel('language',fontsize=14)
plt.ylabel('range',fontsize=14)
plt.title('language vs  range',fontsize=14)
Color=["r","b","y","g","o"]
#plt.bar(x,y,width=0.5,align='center',color='pink',edgecolor='red',linewidth=4,linestyle=':',alpha=0.4)
#width=0.3

plt.bar(x,y,width,color="r",label="sidd")
plt.barh(x,z,width,color="y",label="raju")

#plt.xticks(p+width/2,x,rotation=12)
plt.legend()
plt.show()

# %% [markdown]
# # histogram

# %%
import random

# %%
S=np.random.randint(10,60,(50))
print(S)
# Out:
# [36 25 11 19 32 52 51 21 58 31 27 36 14 21 32 30 33 32 33 15 59 10 30 24
#  15 32 30 13 25 19 46 59 43 55 19 28 32 20 34 51 52 37 46 17 47 57 47 23
#  50 30]

# %%
no=[36, 25, 11, 19, 32, 52, 51, 21, 58, 31, 27, 36, 14, 21, 32, 30, 33, 32, 33, 15, 59, 10, 30, 24,
 15, 32, 30, 13, 25, 19, 46, 59, 43,55, 19, 28, 32, 20, 34, 51, 52, 37, 46, 17, 47, 57, 47,23, 50, 30]

l=[10,20,30,40,50]
plt.hist(no,color='red',edgecolor='blue',bins=l,cumulative=-1,bottom=10,align="left")
plt.xlabel('language')
plt.ylabel('limit')
plt.title('language run')
plt.show()

# %%
no=[36, 25, 11, 19, 32, 52, 51, 21, 58, 31, 27, 36, 14, 21, 32, 30, 33, 32, 33, 15, 59, 10, 30, 24,
 15, 32, 30, 13, 25, 19, 46, 59, 43,55, 19, 28, 32, 20, 34, 51, 52, 37, 46, 17, 47, 57, 47,23, 50, 30]

l=[10,20,30,40,50]
plt.hist(no,color='red',edgecolor='blue',bins=l,cumulative=-1,bottom=10,align="left",histtype='step')
plt.xlabel('language')
plt.ylabel('limit')
plt.title('language run')
plt.show()

# %%
no=[36, 25, 11, 19, 32, 52, 51, 21, 58, 31, 27, 36, 14, 21, 32, 30, 33, 32, 33, 15, 59, 10, 30, 24,
 15, 32, 30, 13, 25, 19, 46, 59, 43,55, 19, 28, 32, 20, 34, 51, 52, 37, 46, 17, 47, 57, 47,23, 50, 30]

l=[10,20,30,40,50]
plt.hist(no,color='red',edgecolor='blue',bins=l,cumulative=-1,bottom=10,align="left",histtype='barstacked',rwidth=0.8,log=True)
plt.xlabel('language')
plt.ylabel('limit')
plt.title('language run')
plt.show()

# %%
no=[36, 25, 11, 19, 32, 52, 51, 21, 58, 31, 27, 36, 14, 21, 32, 30, 33, 32, 33, 15, 59, 10, 30, 24,
 15, 32, 30, 13, 25, 19, 46, 59, 43,55, 19, 28, 32, 20, 34, 51, 52, 37, 46, 17, 47, 57, 47,23, 50, 30]

l=[10,20,30,40,50]
plt.hist(no,color='red',edgecolor='blue',bins=l,cumulative=-1,bottom=10,align="left",histtype='stepfilled',orientation='horizontal',label="yoo")
plt.xlabel('language')
plt.ylabel('limit')
plt.title('language run')
plt.legend()
plt.show()

# %%
no=[36, 25, 11, 19, 32, 52, 51, 21, 58, 31, 27, 36, 14, 21, 32, 30, 33, 32, 33, 15, 59, 10, 30, 24,
 15, 32, 30, 13, 25, 19, 46, 59, 43,55, 19, 28, 32, 20, 34, 51, 52, 37, 46, 17, 47, 57, 47,23, 50, 30]

l=[10,20,30,40,50]
plt.hist(no, "auto",(0,200),color='red',edgecolor='blue')
plt.xlabel('language')
plt.ylabel('limit')
plt.title('language run')
plt.show()

# %%
no=[36, 25, 11, 19, 32, 52, 51, 21, 58, 31, 27, 36, 14, 21, 32, 30, 33, 32, 33, 15, 59, 10, 30, 24,
 15, 32, 30, 13, 25, 19, 46, 59, 43,55, 19, 28, 32, 20, 34, 51, 52, 37, 46, 17, 47, 57, 47,23, 50, 30]

l=[10,20,30,40,50]
plt.hist(no,color='m',edgecolor='blue',bins=l,cumulative=-1,bottom=10,align="left")
plt.xlabel('language')
plt.ylabel('limit')
plt.axvline(35,color='g',label="line")  #its divide into two part denotd by line
plt.title('language run')
plt.legend()
plt.grid() #as per your choice
plt.show()

# %% [markdown]
# # pie plot

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=[10,20,30,40]
y=["c","c++","python","java"]
ex=[0.4,0.0,0.0,0.0]
c=["r","g","b","y"]

plt.pie(x,labels=y,explode=ex,colors=c,autopct="%0.1f%%",shadow=True,radius=1.0,labeldistance=0.3,startangle=90,
        textprops={"fontsize":18},counterclock=False,wedgeprops={"linewidth":5,"edgecolor":"m"},center=(3,5))
plt.legend(loc=4)
plt.show()

# %%
x=[10,20,30,40]
y=["c","c++","python","java"]


plt.pie(x,labels=y,radius=1.3,labeldistance=0.8,startangle=180)
plt.show()

# %%
x=[10,20,30,40]
y=["c","c++","python","java"]
ex=[0.4,0.0,0.0,0.0]
c=["r","g","b","y"]

plt.pie(x,labels=y,explode=ex,colors=c,autopct="%0.1f%%",shadow=True,radius=0.6,labeldistance=0.7,startangle=90,
        textprops={"fontsize":14},counterclock=False,wedgeprops={"linewidth":5,"edgecolor":"m"},rotatelabels=False)
plt.legend()
plt.title("yoo")
plt.show()

# %%
x=[10,20,30,40]
x1=[20,45,31,42,27]
y=["c","c++","python","java"]


plt.pie(x,labels=y,radius=1.4)
plt.pie(x1,radius=0.5)
plt.show()

# %%
x=[10,20,30,40]
x1=[20,45,31,42,27]
y=["c","c++","python","java"]
c=["r","g","b","y"]

plt.pie(x,labels=y,radius=1.4)
plt.pie(x1,radius=1.0,colors="w")
plt.show()

# %% [markdown]
# # stem plot

# %%
x=[1,2,3,4,5,6]
y=[1,2,3,4,6,7]

plt.stem(x,y,linefmt=":",markerfmt="r+",bottom=-2)
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[1,2,3,4,6,7]

plt.stem(x,y,linefmt=":")
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[1,2,3,4,6,7]

plt.stem(x,y,linefmt=":",markerfmt="r+",bottom=0,basefmt="g",label="python",use_line_collection=False)
plt.legend()
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[1,2,3,4,6,7]

plt.stem(x,y,linefmt=":",markerfmt="r+",bottom=0,basefmt="g",label="python",use_line_collection=True) #for line coloring
plt.legend()
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[1,2,3,4,6,7]

plt.stem(x,y,linefmt=":",markerfmt="r+",bottom=0,basefmt="g",label="python",use_line_collection=True,orientation='horizontal') #for line coloring
plt.legend()
plt.show()

# %% [markdown]
# # box plot & whisker plot

# %%
x=[10,20,30,40,50,60]

plt.boxplot(x)

plt.show()

# %%
x=[10,20,30,40,50,60]

plt.boxplot(x,notch=True)

plt.show()

# %%
x=[10,20,30,40,50,60]

plt.boxplot(x,notch=False,vert=True,widths=0.9,labels=["python"],patch_artist=True,showmeans=True) #patch_atrist for fill the color int box

plt.show()

# %%
x=[10,20,30,40,50,60]

plt.boxplot(x,notch=False,vert=False)

plt.show()

# %%
x=[10,20,30,40,50,60]

plt.boxplot(x,notch=False,vert=True,widths=0.9,labels=["python"])

plt.show()

# %%
x=[10,20,30,40,50,60,120]

plt.boxplot(x,notch=False,vert=True,widths=0.9,labels=["python"],whis=7.6)  # whis is use to joint the line

plt.show()   # . shows the outlier part

# %%
x=[10,20,30,40,50,60,120]

plt.boxplot(x,notch=False,vert=True,widths=0.9,labels=["python"],sym="g+",boxprops=dict(color="g"))  #sym is use for color changes in outlier and sign change as +
plt.show()

# %%
x=[10,20,30,40,50,60,120]

plt.boxplot(x,notch=False,vert=True,widths=0.9,labels=["python"],sym="g+",boxprops=dict(color="g"),capprops=dict(color="r"))  
plt.show()

# %%
x=[10,20,30,40,50,60,120]

plt.boxplot(x,notch=False,vert=True,widths=0.9,labels=["python"],sym="g+",boxprops=dict(color="g"),capprops=dict(color="r"),
            whiskerprops=dict(color="b"))  
plt.show()

# %%
x=[10,20,30,40,50,60,120]
x1=[10,33,43,54,63,72]
y=[x,x1]

plt.boxplot(y,labels=["python","c++"],notch=False,vert=True,widths=0.4,sym="g+",boxprops=dict(color="g"))  
plt.show()

# %% [markdown]
# # area chart

# %%
x=[1,2,3,4,5]
area=[1,3,4,8,9]

plt.stackplot(x,area)
plt.show()

# %%
x=[1,2,3,4,5]
area1=[1,3,4,8,9]
area2=[1,3,4,5,6]
area3=[1,3,4,5,6]

plt.stackplot(x,area1,area2,area3)
plt.show()

# %%
x=[1,2,3,4,5]
area1=[1,3,4,8,9]
area2=[1,3,4,5,6]
area3=[1,3,4,5,6]
l=["area1","area2","area3"]


plt.stackplot(x,area1,area2,area3,labels=l,colors=["r","g","m"])
plt.legend()
plt.show()

# %%
x=[1,2,3,4,5]
area1=[1,3,4,8,9]
area2=[1,3,4,5,6]
area3=[1,3,4,5,6]
l=["area1","area2","area3"]


plt.stackplot(x,area1,area2,area3,labels=l,colors=["r","g","m"],baseline="zero")
plt.legend()
plt.title("yoo")
plt.xlabel("x_axis")
plt.ylabel("y_axis")
plt.show()

# %%
x=[1,2,3,4,5]
area1=[1,3,4,8,9]
area2=[1,3,4,5,6]
area3=[1,3,4,5,6]
l=["area1","area2","area3"]


plt.stackplot(x,area1,area2,area3,labels=l,colors=["r","g","m"],baseline="sym")   #uses of baseline parameter
plt.legend()
plt.show()

# %%
x=[1,2,3,4,5]
area1=[1,3,4,8,9]
area2=[1,3,4,5,6]
area3=[1,3,4,5,6]
l=["area1","area2","area3"]


plt.stackplot(x,area1,area2,area3,labels=l,colors=["r","g","m"],baseline="wiggle")
plt.legend()
plt.show()

# %% [markdown]
# # step plot

# %%
x=[1,3,4,9,2]
y=[3,6,1,3,3]

plt.step(x,y)
plt.title("yoo")
plt.xlabel("x_axis")
plt.ylabel("y_axis")

plt.show()

# %%
x=[1,3,4,9,2]
y=[3,6,1,3,3]

plt.step(x,y,color="r",marker="o",ms=10,mfc="g",label="python")
plt.title("yoo")
plt.xlabel("x_axis")
plt.ylabel("y_axis")
plt.legend(loc=2)
plt.grid()
plt.show()

# %% [markdown]
# # file btween plot

# %%
x=[1,3,4,5,6]
y=[1,2,3,4,5]

plt.plot(x,y)
plt.xlabel("x_axis")
plt.ylabel("y_axis")
plt.title("yoo")

plt.show()

# %%
x=[1,3,4,5,6]
y=[1,2,3,4,5]


plt.plot(x,y,color="r")

plt.fill_between(x=[2,4],y1=2,y2=4)
plt.xlabel("x_axis")
plt.ylabel("y_axis")
plt.title("yoo")

plt.show()

# %%
x=[1,3,4,5,6]
y=[1,2,3,4,5]


plt.plot(x,y,color="r")

plt.fill_between(x,y,color="r")
plt.xlabel("x_axis")
plt.ylabel("y_axis")
plt.title("yoo")

plt.show()

# %%
x=np.array([1,3,4,9,6])
y=np.array([1,2,7,4,5])


plt.plot(x,y,color="r")

plt.fill_between(x,y,color="r",where=(x>=2)&(x<=9),alpha=0.3)
plt.xlabel("x_axis")
plt.ylabel("y_axis")
plt.title("yoo")

plt.show()

# %% [markdown]
# # saveflg

# %%
x=[1,2,3,4,5]
y=[1,2,4,6,7]

plt.plot(x,y)
plt.title("yoo")

plt.savefig("linename",dpi=200,facecolor="g")
plt.show()
